# %% [markdown]
# # 01 — Data exploration
# Load the raw occupancy table and inspect schema, coverage, and libraries.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.data.load import load_raw
df = load_raw()
print(df.shape)
print(df.dtypes)
print(df.timestamp.min(), df.timestamp.max())
df.groupby(["library_id","zone_id"]).size().head()
