# %% [markdown]
# # 02 — Exploratory data analysis
#
# Temporal patterns, academic-calendar effects, distributions, correlations, missingness, and anomalies.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.data.load import load_raw
from src.data.clean import clean_occupancy
from src.features.transformers import prepare_frame
from src.viz.plots import (
    occupancy_by_hour, occupancy_by_weekday, weekday_vs_weekend,
    exam_vs_normal, occupancy_distribution, correlation_heatmap,
    missingness_bar, daily_trend,
)

raw = load_raw()
clean = clean_occupancy(raw)
frame = prepare_frame(clean)
raw.head()

# %%
missingness_bar(raw).show()
daily_trend(frame).show()
occupancy_by_hour(frame).show()
occupancy_by_weekday(frame).show()
weekday_vs_weekend(frame).show()
exam_vs_normal(frame).show()
occupancy_distribution(frame).show()
correlation_heatmap(frame).show()
